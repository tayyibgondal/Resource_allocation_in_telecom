# %%
import matplotlib.pyplot as plt

# Data
train_set_size = [1000, 10000, 20000, 40000, 60000, 80000, 90000]

# SE values
se_llama = [26.05, 26.01, 26, 25.91, 25.53, 26.31, 24.73]
se_code_llama = [25.78, 25.9, 25.6, 25.76, 26.94, 25.78, 25.6]
se_mistral = [25.79, 27.69, 25.78, 25.78, 26.84, 25.8, 25.78]
se_phi = [25.85, 27.79, 26.2, 25.91, 26.13, 26.04, 25.98]

# EE values
ee_llama = [26.37, 26.82, 26.37, 26.82, 26.36, 26.43, 26.64]
ee_code_llama = [26.34, 26.86, 23.44, 25.89, 26.28, 26.28, 23.44]
ee_mistral = [26.39, 26.61, 26.39, 26.78, 25.02, 26.38, 26.38]
ee_phi = [26.46, 26.67, 26.99, 26.78, 27.13, 26.13, 26.16]

# Plotting SE values
plt.figure(figsize=(10, 6))
plt.plot(train_set_size, se_llama, label='LLAMA SE', marker='o', color='b')
plt.plot(train_set_size, se_code_llama, label='Code-LLAMA SE', marker='o', color='g')
plt.plot(train_set_size, se_mistral, label='Mistral SE', marker='o', color='r')
plt.plot(train_set_size, se_phi, label='PHI SE', marker='o', color='purple')
plt.axhline(y=29.49, color='k', linestyle='--', label='Optimal SE Baseline')
plt.axhline(y=21.3, color='c', linestyle='--', label='Random SE Baseline')
plt.xlabel('Training Set Size')
plt.ylabel('SE Values')
plt.title('SE values vs Training Set Size for Multiple LLMs')
plt.legend()
plt.grid(True)
plt.show()

# Plotting EE values
plt.figure(figsize=(10, 6))
plt.plot(train_set_size, ee_llama, label='LLAMA EE', marker='o', color='b')
plt.plot(train_set_size, ee_code_llama, label='Code-LLAMA EE', marker='o', color='g')
plt.plot(train_set_size, ee_mistral, label='Mistral EE', marker='o', color='r')
plt.plot(train_set_size, ee_phi, label='PHI EE', marker='o', color='purple')
plt.axhline(y=31.36, color='k', linestyle='--', label='Optimal EE Baseline')
plt.axhline(y=21.34, color='c', linestyle='--', label='Random EE Baseline')
plt.xlabel('Training Set Size')
plt.ylabel('EE Values')
plt.title('EE values vs Training Set Size for Multiple LLMs')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
train_set_size = [1000, 10000, 20000, 40000, 60000, 80000, 90000]

# SE values
se_llama = [26.05, 26.01, 26, 25.91, 25.53, 26.31, 24.73]
se_code_llama = [25.78, 25.9, 25.6, 25.76, 26.94, 25.78, 25.6]
se_mistral = [25.79, 27.69, 25.78, 25.78, 26.84, 25.8, 25.78]
se_phi = [25.85, 27.79, 26.2, 25.91, 26.13, 26.04, 25.98]

# EE values
ee_llama = [26.37, 26.82, 26.37, 26.82, 26.36, 26.43, 26.64]
ee_code_llama = [26.34, 26.86, 23.44, 25.89, 26.28, 26.28, 23.44]
ee_mistral = [26.39, 26.61, 26.39, 26.78, 25.02, 26.38, 26.38]
ee_phi = [26.46, 26.67, 26.99, 26.78, 27.13, 26.13, 26.16]

# Random baselines
random_se = 21.3
random_ee = 21.34

# Calculate percentage improvement over random baseline for SE
se_llama_improvement = [(val - random_se) / random_se * 100 for val in se_llama]
se_code_llama_improvement = [(val - random_se) / random_se * 100 for val in se_code_llama]
se_mistral_improvement = [(val - random_se) / random_se * 100 for val in se_mistral]
se_phi_improvement = [(val - random_se) / random_se * 100 for val in se_phi]

# Calculate percentage improvement over random baseline for EE
ee_llama_improvement = [(val - random_ee) / random_ee * 100 for val in ee_llama]
ee_code_llama_improvement = [(val - random_ee) / random_ee * 100 for val in ee_code_llama]
ee_mistral_improvement = [(val - random_ee) / random_ee * 100 for val in ee_mistral]
ee_phi_improvement = [(val - random_ee) / random_ee * 100 for val in ee_phi]

# Plotting SE percentage improvement
plt.figure(figsize=(10, 6))
x = np.arange(len(train_set_size))
bar_width = 0.2

plt.bar(x - 1.5 * bar_width, se_llama_improvement, width=bar_width, label='LLAMA SE')
plt.bar(x - 0.5 * bar_width, se_code_llama_improvement, width=bar_width, label='Code-LLAMA SE')
plt.bar(x + 0.5 * bar_width, se_mistral_improvement, width=bar_width, label='Mistral SE')
plt.bar(x + 1.5 * bar_width, se_phi_improvement, width=bar_width, label='PHI SE')

plt.xlabel('Training Set Size')
plt.ylabel('Percentage Improvement over Random SE (%)')
plt.title('Percentage Improvement in SE over Random Baseline for Multiple LLMs')
plt.xticks(x, [str(size) + 'k' for size in np.array(train_set_size) / 1000])
plt.legend()
plt.grid(True)
plt.show()

# Plotting EE percentage improvement
plt.figure(figsize=(10, 6))
plt.bar(x - 1.5 * bar_width, ee_llama_improvement, width=bar_width, label='LLAMA EE')
plt.bar(x - 0.5 * bar_width, ee_code_llama_improvement, width=bar_width, label='Code-LLAMA EE')
plt.bar(x + 0.5 * bar_width, ee_mistral_improvement, width=bar_width, label='Mistral EE')
plt.bar(x + 1.5 * bar_width, ee_phi_improvement, width=bar_width, label='PHI EE')

plt.xlabel('Training Set Size')
plt.ylabel('Percentage Improvement over Random EE (%)')
plt.title('Percentage Improvement in EE over Random Baseline for Multiple LLMs')
plt.xticks(x, [str(size) + 'k' for size in np.array(train_set_size) / 1000])
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
train_set_size = [1000, 10000, 20000, 40000, 60000, 80000, 90000]

# SE values
se_llama = [26.05, 26.01, 26, 25.91, 25.53, 26.31, 24.73]
se_code_llama = [25.78, 25.9, 25.6, 25.76, 26.94, 25.78, 25.6]
se_mistral = [25.79, 27.69, 25.78, 25.78, 26.84, 25.8, 25.78]
se_phi = [25.85, 27.79, 26.2, 25.91, 26.13, 26.04, 25.98]

# EE values
ee_llama = [26.37, 26.82, 26.37, 26.82, 26.36, 26.43, 26.64]
ee_code_llama = [26.34, 26.86, 23.44, 25.89, 26.28, 26.28, 23.44]
ee_mistral = [26.39, 26.61, 26.39, 26.78, 25.02, 26.38, 26.38]
ee_phi = [26.46, 26.67, 26.99, 26.78, 27.13, 26.13, 26.16]

# Random baselines
random_se = 21.3
random_ee = 21.34

# Calculate total percentage improvement over random baseline for SE
se_llama_total_improvement = sum([(val - random_se) / random_se * 100 for val in se_llama])
se_code_llama_total_improvement = sum([(val - random_se) / random_se * 100 for val in se_code_llama])
se_mistral_total_improvement = sum([(val - random_se) / random_se * 100 for val in se_mistral])
se_phi_total_improvement = sum([(val - random_se) / random_se * 100 for val in se_phi])

# Calculate total percentage improvement over random baseline for EE
ee_llama_total_improvement = sum([(val - random_ee) / random_ee * 100 for val in ee_llama])
ee_code_llama_total_improvement = sum([(val - random_ee) / random_ee * 100 for val in ee_code_llama])
ee_mistral_total_improvement = sum([(val - random_ee) / random_ee * 100 for val in ee_mistral])
ee_phi_total_improvement = sum([(val - random_ee) / random_ee * 100 for val in ee_phi])

# Plotting total SE percentage improvement
llms = ['LLAMA', 'Code-LLAMA', 'Mistral', 'PHI']
se_total_improvements = [se_llama_total_improvement, se_code_llama_total_improvement, se_mistral_total_improvement, se_phi_total_improvement]

plt.figure(figsize=(8, 5))
plt.bar(llms, se_total_improvements, color=['b', 'g', 'r', 'purple'])
plt.ylabel('Total Percentage Improvement over Random SE (%)')
plt.title('Total SE Improvement over Random Baseline for Multiple LLMs')
plt.grid(True)
plt.show()

# Plotting total EE percentage improvement
ee_total_improvements = [ee_llama_total_improvement, ee_code_llama_total_improvement, ee_mistral_total_improvement, ee_phi_total_improvement]

plt.figure(figsize=(8, 5))
plt.bar(llms, ee_total_improvements, color=['b', 'g', 'r', 'purple'])
plt.ylabel('Total Percentage Improvement over Random EE (%)')
plt.title('Total EE Improvement over Random Baseline for Multiple LLMs')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for peak reserved memory during training for the four LLMs
llms = ['LLAMA', 'Code-LLAMA', 'Mistral', 'PHI']
peak_reserved_mem = [6.562, 4.469, 5.1, 2.594]  # in GB

# Plotting
plt.figure(figsize=(8, 5))

# Create the bar plot with a color scheme
bars = plt.bar(llms, peak_reserved_mem, color=['#1f77b4', '#2ca02c', '#d62728', '#9467bd'])  # Use hex colors for better aesthetics

# Adding data labels on top of each bar for clarity
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', fontsize=12)

# Axis labels and title
plt.ylabel('Peak Reserved Memory (GB)', fontsize=14, weight='bold')
plt.title('Peak Reserved Memory Usage During Training for Multiple LLMs', fontsize=16, weight='bold')

# Turn off grid lines
plt.grid(False)

# Adjust the layout to prevent clipping
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for spectral efficiency values with different rank parameters
rank_parameters = [8, 16, 32, 64, 128, 256]
spectral_efficiency_values = [26.94, 26.95, 26.46, 26.36, 25.247, 25.240]

# Apply a more professional built-in style
plt.style.use('ggplot')  # Use a valid style like 'ggplot'

# Plotting
plt.figure(figsize=(8, 5))

# Use a thicker line, larger markers, and a more elegant color scheme
plt.plot(rank_parameters, spectral_efficiency_values, marker='o', color='darkblue', 
         markersize=10, linewidth=2, label='Spectral Efficiency')

# Ensure that x-axis shows all values, including 256
plt.xticks(rank_parameters, fontsize=12)
plt.yticks(fontsize=12)

# Labeling the axes
plt.xlabel('Rank Parameter (r)', fontsize=14, weight='bold')
plt.ylabel('Spectral Efficiency', fontsize=14, weight='bold')

# Title with proper formatting
plt.title('Spectral Efficiency vs Rank Parameter for CodeLlama Fine-Tuning', fontsize=16, weight='bold')

# Turn off grid lines
plt.grid(False)

# Add a legend with a larger font
plt.legend(fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for energy efficiency for 2 users and 3 users
ee_pred_2_users = 26.46
ee_optimal_2_users = 31.36
ee_pred_3_users = 25.88
ee_optimal_3_users = 36.18
# Data for spectral efficiency for 2 users and 3 users
se_pred_2_users = 25.85
se_optimal_2_users = 29.49
se_pred_3_users = 26.15
se_optimal_3_users = 33.14

# Calculate percentage of optimal power achieved by LLM for spectral efficiency
predicted_vs_optimal_se_2_users = (se_pred_2_users / se_optimal_2_users) * 100
predicted_vs_optimal_se_3_users = (se_pred_3_users / se_optimal_3_users) * 100
# Calculate percentage of optimal power achieved by LLM for energy efficiency
predicted_vs_optimal_ee_2_users = (ee_pred_2_users / ee_optimal_2_users) * 100
predicted_vs_optimal_ee_3_users = (ee_pred_3_users / ee_optimal_3_users) * 100

# Labels for users
users = ['2 Users', '3 Users']

# Plotting side-by-side comparison of spectral and energy efficiencies
plt.figure(figsize=(8, 5))

bar_width = 0.35  # Reduced bar width

# Spectral Efficiency
plt.bar([x - bar_width / 2 for x in range(len(users))], 
        [predicted_vs_optimal_se_2_users, predicted_vs_optimal_se_3_users], 
        width=bar_width, label='Spectral Efficiency', color='g', alpha=0.75)

# Energy Efficiency
plt.bar([x + bar_width / 2 for x in range(len(users))], 
        [predicted_vs_optimal_ee_2_users, predicted_vs_optimal_ee_3_users], 
        width=bar_width, label='Energy Efficiency', color='b', alpha=0.75)

# Customizing the plot
plt.xlabel('Number of Users', fontsize=12)
plt.ylabel('Percentage of Optimal Achieved (%)', fontsize=12)
plt.title('Predicted vs Optimal SE and EE for 2 Users vs 3 Users', fontsize=14)
plt.ylim(20, 90)  # Set y-axis limit for better comparison
plt.xticks(range(len(users)), users)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for spectral efficiency values with different k values
k_values = [2, 4, 6, 8, 10, 12]
spectral_efficiency_values = [30.04, 31.58, 30.26, 30.74, 31.9, 31.4]

# Apply a more professional built-in style
plt.style.use('ggplot')  # Use a valid style like 'ggplot'

# Plotting
plt.figure(figsize=(8, 5))

# Use a thicker line, larger markers, and a more elegant color scheme
plt.plot(k_values, spectral_efficiency_values, marker='o', color='darkblue', 
         markersize=10, linewidth=2, label='Spectral Efficiency')

# Ensure that x-axis shows all values, including 256
plt.xticks(k_values, fontsize=12)
plt.yticks(fontsize=12)

# Labeling the axes
plt.xlabel('K Values for Rician Fading', fontsize=14, weight='bold')
plt.ylabel('Spectral Efficiency', fontsize=14, weight='bold')

# Title with proper formatting
plt.title('Spectral Efficiency vs K Values for Phi Fine-Tuning', fontsize=16, weight='bold')

# Turn off grid lines
plt.grid(False)

# Add a legend with a larger font
plt.legend(fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for energy efficiency values with different k values
k_values = [2, 4, 6, 8, 10, 12]
energy_efficiency_values = [29.21, 30.93, 31.44, 32.69, 33.46, 32.33]

# Apply a more professional built-in style
plt.style.use('ggplot')  # Use a valid style like 'ggplot'

# Plotting
plt.figure(figsize=(8, 5))

# Use a thicker line, larger markers, and a more elegant color scheme
plt.plot(k_values, spectral_efficiency_values, marker='o', color='darkblue', 
         markersize=10, linewidth=2, label='Energy Efficiency')

# Ensure that x-axis shows all values, including 256
plt.xticks(k_values, fontsize=12)
plt.yticks(fontsize=12)

# Labeling the axes
plt.xlabel('K Values for Rician Fading', fontsize=14, weight='bold')
plt.ylabel('Energy Efficiency', fontsize=14, weight='bold')

# Title with proper formatting
plt.title('Energy Efficiency vs. K Values for Phi Fine-Tuning', fontsize=16, weight='bold')

# Turn off grid lines
plt.grid(False)

# Add a legend with a larger font
plt.legend(fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for energy efficiency for rician and rayleigh fading 
se_pred_rayleigh = 25.85
se_optimal_rayleigh = 29.49

se_pred_rician_k_4 = 31.58
se_optimal_rician_k_4 = 32.27

se_pred_rician_k_8 = 30.74
se_optimal_rician_k_8 = 32.75

se_pred_rician_k_12 = 31.4
se_optimal_rician_k_12 = 33.59

se_pred_rician_k_2 = 30.04
se_optimal_rician_k_2 = 31.54

se_pred_rician_k_6 = 30.26
se_optimal_rician_k_6 = 32.87

se_pred_rician_k_10 = 31.9
se_optimal_rician_k_10 = 33.48

# Data for spectral efficiency for rician and rayleigh fading 
ee_pred_rayleigh = 26.46
ee_optimal_rayleigh = 31.36

ee_pred_rician_k_4 = 30.93
ee_optimal_rician_k_4 = 33.54

ee_pred_rician_k_8 = 32.69
ee_optimal_rician_k_8 = 34.82

ee_pred_rician_k_12 = 32.33
ee_optimal_rician_k_12 = 35.23

ee_pred_rician_k_2 = 29.21
ee_optimal_rician_k_2 = 33.12

ee_pred_rician_k_6 = 31.44
ee_optimal_rician_k_6 = 33.5

ee_pred_rician_k_10 = 33.46
ee_optimal_rician_k_10 = 35.06

# Calculate percentage of optimal power achieved by LLM for energy efficiency
predicted_vs_optimal_ee_rayleigh = (ee_pred_rayleigh / ee_optimal_rayleigh) * 100
predicted_vs_optimal_ee_rician_k_4 = (ee_pred_rician_k_4 / ee_optimal_rician_k_4) * 100
predicted_vs_optimal_ee_rician_k_8 = (ee_pred_rician_k_8 / ee_optimal_rician_k_8) * 100
predicted_vs_optimal_ee_rician_k_12 = (ee_pred_rician_k_12 / ee_optimal_rician_k_12) * 100
predicted_vs_optimal_ee_rician_k_2 = (ee_pred_rician_k_2 / ee_optimal_rician_k_2) * 100
predicted_vs_optimal_ee_rician_k_6 = (ee_pred_rician_k_6 / ee_optimal_rician_k_6) * 100
predicted_vs_optimal_ee_rician_k_10 = (ee_pred_rician_k_10 / ee_optimal_rician_k_10) * 100

# Calculate percentage of optimal power achieved by LLM for spectral efficiency
predicted_vs_optimal_se_rayleigh = (se_pred_rayleigh / se_optimal_rayleigh) * 100
predicted_vs_optimal_se_rician_k_4 = (se_pred_rician_k_4 / se_optimal_rician_k_4) * 100
predicted_vs_optimal_se_rician_k_8 = (se_pred_rician_k_8 / se_optimal_rician_k_8) * 100
predicted_vs_optimal_se_rician_k_12 = (se_pred_rician_k_12 / se_optimal_rician_k_12) * 100
predicted_vs_optimal_se_rician_k_2 = (se_pred_rician_k_2 / se_optimal_rician_k_2) * 100
predicted_vs_optimal_se_rician_k_6 = (se_pred_rician_k_6 / se_optimal_rician_k_6) * 100
predicted_vs_optimal_se_rician_k_10 = (se_pred_rician_k_10 / se_optimal_rician_k_10) * 100

# Labels 
fading = ['Rayleigh(K=0)', 'Rician(K=2)', 'Rician(K=4)', 'Rician(K=6)', 'Rician(K=8)', 'Rician(K=10)', 'Rician(K=12)']

# Plotting side-by-side comparison of spectral and energy efficiencies
plt.figure(figsize=(8, 5))

bar_width = 0.35  # Reduced bar width

# Spectral Efficiency
plt.bar([x - bar_width / 2 for x in range(len(fading))], 
        [predicted_vs_optimal_ee_rayleigh, predicted_vs_optimal_ee_rician_k_2, predicted_vs_optimal_ee_rician_k_4, predicted_vs_optimal_ee_rician_k_6, predicted_vs_optimal_ee_rician_k_8, predicted_vs_optimal_ee_rician_k_10, predicted_vs_optimal_ee_rician_k_12], 
        width=bar_width, label='Energy Efficiency', color='g', alpha=0.75)

# Energy Efficiency
plt.bar([x + bar_width / 2 for x in range(len(fading))], 
        [predicted_vs_optimal_se_rayleigh, predicted_vs_optimal_se_rician_k_2, predicted_vs_optimal_se_rician_k_4, predicted_vs_optimal_se_rician_k_6, predicted_vs_optimal_se_rician_k_8, predicted_vs_optimal_se_rician_k_10, predicted_vs_optimal_se_rician_k_12], 
        width=bar_width, label='Spectral Efficiency', color='b', alpha=0.75)

# Customizing the plot
plt.xlabel('Fading Type', fontsize=12)
plt.ylabel('Percentage of Optimal Achieved (%)', fontsize=12)
plt.title('Predicted vs. Optimal SE and EE for Rayleigh vs. Rician Fading', fontsize=14)
plt.ylim(60, 100)  # Set y-axis limit for better comparison
plt.xticks(range(len(fading)), fading)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
